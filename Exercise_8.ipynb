# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexzanderReyes/VDA-CpE-031-CpE-21S4/blob/main/Exercise_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas #Installation of Matplotlib

# %%
import matplotlib #adding module

# %%
import matplotlib.pyplot as plt #adding module
import numpy as np

xpoints = np.array([0, 6]) #plotting x and y points
ypoints = np.array([0, 10])

plt.plot(xpoints, ypoints) #plot is used to draw point
plt.show()

# %%
import matplotlib.pyplot as plt #adding module
import numpy as np

xpoints = np.array([0, 6]) #plotting x and y points
ypoints = np.array([0, 10])

plt.plot(xpoints, ypoints, 'o') #plot is used to draw point
plt.show()

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])

plt.plot(xpoints,ypoints)
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,marker = 'o')
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,marker = 'x')
plt.show()

# %%
ypoints=np.array([3,8,1,10])

plt.plot(ypoints,'o:b', ms = 10,mec='r')
plt.show()

# %%
plt.plot(ypoints,linestyle = 'dashed')
plt.show()

# %%
plt.plot(ypoints,linestyle = 'dotted')
plt.show()

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])

plt.plot(xpoints,ypoints)

plt.title("Distance Travelled Everyday")
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")

plt.show()

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])

plt.plot(xpoints,ypoints)

plt.title("Distance Travelled Everyday", loc="left")
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")

plt.show()

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])

plt.plot(xpoints,ypoints)

plt.title("Distance Travelled Everyday", )
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.grid(axis='y')
plt.show()

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])

plt.plot(xpoints,ypoints)

plt.title("Distance Travelled Everyday", )
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.grid(axis='x', linestyle = '--', linewidth=0.50)
plt.show()

# %%
#plot1
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(xpoints,ypoints)
#plot2
xpoints=np.array([1,2,6,8])
ypoints=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(xpoints,ypoints)


plt.grid(axis='x', linestyle = '--', linewidth=0.50)
plt.show()

# %%
#plot1
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])

plt.scatter(xpoints,ypoints)
xpoint=np.array([1,2,6,8])
ypoint=np.array([10,20,30,40])
plt.scatter(xpoint,ypoint)

plt.grid(axis='x', linestyle = '--', linewidth=0.50)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array(["Student1","Student2","Student3"])
ypoints=np.array([90,85,86])

# You need to use the defined variables 'xpoints' and 'ypoints' here:
plt.bar(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
g= np.array([35,25,25,15])
grader=["Grade 1=35%","Grade 2=25%","Grade 3=25%","Grade 4=15%"]
plt.pie(g,labels=grader)
plt.show()

# %%
def convert_to_seconds(time_str):
    try:
        minutes, seconds = map(int, time_str.split(':'))
        return minutes * 60 + seconds
    except ValueError:
        print(f"Error converting time: {time_str}")
        return None  # Handle conversion error

# Check the exact name of the 'Song Length' column and apply the conversion
# Replace 'Song Length' with the actual column name if different
if 'Song Length' in df.columns:
    df['Song Length (Seconds)'] = df['Song Length'].apply(convert_to_seconds)
else:
    print("Column 'Song Length' not found in the dataset.")

# Create a line plot: Song position vs. Song Length
plt.figure(figsize=(12, 6))

# Use df.index for song position; adjust accordingly if there's a specific position column
plt.plot(df.index, df['Song Length (Seconds)'], color='green', marker='o', linestyle='dashed')

# Add titles and labels
plt.title('Song Position vs. Song Length')
plt.xlabel('Song Position (Index)')
plt.ylabel('Song Length (Seconds)')
plt.grid()  # Optional: add grid for better readability

# Show the line chart
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-2b66eb634559> in <cell line: 11>()
#       9 # Check the exact name of the 'Song Length' column and apply the conversion
#      10 # Replace 'Song Length' with the actual column name if different
# ---> 11 if 'Song Length' in df.columns:
#      12     df['Song Length (Seconds)'] = df['Song Length'].apply(convert_to_seconds)
#      13 else:
#
# NameError: name 'df' is not defined
