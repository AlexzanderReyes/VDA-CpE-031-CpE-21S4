# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexzanderReyes/VDA-CpE-031-CpE-21S4/blob/main/Exercise3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import csv file using pandas
# !pip install pandas

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-42ecf1bd-dd8c-4e43-ad9b-c2852e6b038e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-42ecf1bd-dd8c-4e43-ad9b-c2852e6b038e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('Grade.csv')
print(df)

print(df.head(10)) # 10 rows from the top
print(df.tail(10)) # 10 rows from the bottom
# Out:
#     CpE 0323-1  Quiz 1  Python Fundamentals  Conditional Statements  \
# 0         Name      50                  100                     100
# 1    STUDENT 1      33                  100                     100
# 2    STUDENT 2      22                  100                     100
# 3    STUDENT 3      42                  100                     100
# 4    STUDENT 4      34                  100                     100
# 5    STUDENT 5      38                  100                     100
# 6    STUDENT 6      30                  100                     100
# 7    STUDENT 7      24                  100                     100
# 8    STUDENT 8      37                  100                     100
# 9    STUDENT 9       0                  100                     100
# 10  STUDENT 10      43                  100                     100
# 11  STUDENT 11      35                  100                     100
# 12  STUDENT 12      41                  100                     100
# ...

# %%
print(df.duplicated())
df.drop_duplicates(inplace = True)
print(df)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# dtype: bool
#     CpE 0323-1  Quiz 1  Python Fundamentals  Conditional Statements  \
# 0         Name      50                  100                     100
# 1    STUDENT 1      33                  100                     100
# 2    STUDENT 2      22                  100                     100
# 3    STUDENT 3      42                  100                     100
# 4    STUDENT 4      34                  100                     100
# 5    STUDENT 5      38                  100                     100
# 6    STUDENT 6      30                  100                     100
# ...

# %%
from tabulate import tabulate
df.drop_duplicates(inplace = True)
print(tabulate(df, headers='keys', tablefmt='psql',showindex=False))
# Out:
# +--------------+----------+-----------------------+--------------------------+------------------+------------------+---------------------+---------+---------+---------+---------+---------+
# | CpE 0323-1   |   Quiz 1 |   Python Fundamentals |   Conditional Statements |   Loop Statement |   Data Structure |   Image Acquisition |   Lab 1 |   Lab 2 |   Lab 3 |   Lab 4 |   Lab 5 |
# |--------------+----------+-----------------------+--------------------------+------------------+------------------+---------------------+---------+---------+---------+---------+---------|
# | Name         |       50 |                   100 |                      100 |              100 |              100 |                 100 |     100 |     100 |     100 |     100 |     100 |
# | STUDENT 1    |       33 |                   100 |                      100 |              100 |              100 |                 100 |      90 |      90 |      90 |      90 |      90 |
# ...

# %%
#1 Import SampleData.csv to Google Colab
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c0f63474-4da4-4aa0-9b66-516fe2e0ed9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0f63474-4da4-4aa0-9b66-516fe2e0ed9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#2 Read the contexts of SampleData.csv
import pandas as pd
df = pd.read_csv('SampleData.csv')
print(df)
# Out:
#    OrderDate   Region       Rep     Item  Units  Unit Cost       Total
# 0     1/6/21     East     Jones   Pencil     95       1.99     189.05
# 1    1/23/21  Central    Kivell   Binder     50      19.99     999.50
# 2     2/9/21  Central   Jardine   Pencil     36       4.99     179.64
# 3    2/26/21  Central      Gill      Pen     27      19.99     539.73
# 4    3/15/21     West   Sorvino   Pencil     56       2.99     167.44
# 5     4/1/21     East     Jones   Binder     60       4.99     299.40
# 6    4/18/21  Central   Andrews   Pencil     75       1.99     149.25
# 7     5/5/21  Central   Jardine   Pencil     90       4.99     449.10
# 8    5/22/21     West  Thompson   Pencil     32       1.99      63.68
# 9     6/8/21     East     Jones   Binder     60       8.99     539.40
# 10   6/25/21  Central    Morgan   Pencil     90       4.99     449.10
# 11   7/12/21     East    Howard   Binder     29       1.99      57.71
# ...

# %%
#3 Show all top 10 records
import pandas as pd
df = pd.read_csv('SampleData.csv')
print(df.head(10))
# Out:
#   OrderDate   Region       Rep    Item  Units  Unit Cost     Total
# 0    1/6/21     East     Jones  Pencil     95       1.99   189.05
# 1   1/23/21  Central    Kivell  Binder     50      19.99   999.50
# 2    2/9/21  Central   Jardine  Pencil     36       4.99   179.64
# 3   2/26/21  Central      Gill     Pen     27      19.99   539.73
# 4   3/15/21     West   Sorvino  Pencil     56       2.99   167.44
# 5    4/1/21     East     Jones  Binder     60       4.99   299.40
# 6   4/18/21  Central   Andrews  Pencil     75       1.99   149.25
# 7    5/5/21  Central   Jardine  Pencil     90       4.99   449.10
# 8   5/22/21     West  Thompson  Pencil     32       1.99    63.68
# 9    6/8/21     East     Jones  Binder     60       8.99   539.40

# %%
#4 Show all bottom records
import pandas as pd
df = pd.read_csv('SampleData.csv')
print(df.tail(10))
# Out:
#    OrderDate   Region       Rep     Item  Units  Unit Cost       Total
# 33   7/21/22  Central    Morgan  Pen Set     55      12.49     686.95
# 34   7/21/22  Central    Morgan  Pen Set     55      12.49     686.95
# 35   7/21/22  Central    Morgan  Pen Set     55      12.49     686.95
# 36   9/10/22  Central      Gill   Pencil      7       1.29       9.03
# 37   9/27/22     West   Sorvino      Pen     76       1.99     151.24
# 38  10/14/22     West  Thompson   Binder     57      19.99   1,139.43
# 39  10/31/22  Central   Andrews   Pencil     14       1.29      18.06
# 40  11/17/22  Central   Jardine   Binder     11       4.99      54.89
# 41   12/4/22  Central   Jardine   Binder     94      19.99   1,879.06
# 42  12/21/22  Central   Andrews   Binder     28       4.99     139.72

# %%
#5 Eliminate all duplicate records (1)
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# dtype: bool

# %%
#5 Eliminate all duplicate records (2)
df.drop_duplicates(inplace = True)
from tabulate import tabulate
print(tabulate(df, headers='keys', tablefmt='psql',showindex=True))
# Out:
# +----+-------------+----------+----------+---------+---------+-------------+----------+
# |    | OrderDate   | Region   | Rep      | Item    |   Units |   Unit Cost | Total    |
# |----+-------------+----------+----------+---------+---------+-------------+----------|
# |  0 | 1/6/21      | East     | Jones    | Pencil  |      95 |        1.99 | 189.05   |
# |  1 | 1/23/21     | Central  | Kivell   | Binder  |      50 |       19.99 | 999.50   |
# |  2 | 2/9/21      | Central  | Jardine  | Pencil  |      36 |        4.99 | 179.64   |
# |  3 | 2/26/21     | Central  | Gill     | Pen     |      27 |       19.99 | 539.73   |
# |  4 | 3/15/21     | West     | Sorvino  | Pencil  |      56 |        2.99 | 167.44   |
# |  5 | 4/1/21      | East     | Jones    | Binder  |      60 |        4.99 | 299.40   |
# |  6 | 4/18/21     | Central  | Andrews  | Pencil  |      75 |        1.99 | 149.25   |
# |  7 | 5/5/21      | Central  | Jardine  | Pencil  |      90 |        4.99 | 449.10   |
# ...

# %%
#6 Save the context (removed duplicate records) into new file SampleDataNew.csv
df.drop_duplicates(inplace = True)
df.to_csv('SampleDataNew')

# %%
# Save Data
pd.read_csv('SampleDataNew')
# Out:
#     Unnamed: 0 OrderDate   Region       Rep     Item  Units  Unit Cost  \
# 0            0    1/6/21     East     Jones   Pencil     95       1.99
# 1            1   1/23/21  Central    Kivell   Binder     50      19.99
# 2            2    2/9/21  Central   Jardine   Pencil     36       4.99
# 3            3   2/26/21  Central      Gill      Pen     27      19.99
# 4            4   3/15/21     West   Sorvino   Pencil     56       2.99
# 5            5    4/1/21     East     Jones   Binder     60       4.99
# 6            6   4/18/21  Central   Andrews   Pencil     75       1.99
# 7            7    5/5/21  Central   Jardine   Pencil     90       4.99
# 8            8   5/22/21     West  Thompson   Pencil     32       1.99
# 9            9    6/8/21     East     Jones   Binder     60       8.99
# 10          10   6/25/21  Central    Morgan   Pencil     90       4.99
# 11          11   7/12/21     East    Howard   Binder     29       1.99
# ...
